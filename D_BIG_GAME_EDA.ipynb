# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load dataset
file = 'Selected_Online_Casino_Gaming_Data.csv'
data = pd.read_csv(file)

data
# Out:
#                                 Licensee Fiscal Year            Month Ending  \
# 0           Mohegan Tribe On-Reservation     2023/24  05/31/2024 12:00:00 AM
# 1                    MPTN On-Reservation     2023/24  05/31/2024 12:00:00 AM
# 2    MPI Master Wagering License CT, LLC     2023/24  05/31/2024 12:00:00 AM
# 3                   Mohegan Digital, LLC     2023/24  05/31/2024 12:00:00 AM
# 4           Mohegan Tribe On-Reservation     2023/24  04/30/2024 12:00:00 AM
# ..                                   ...         ...                     ...
# 114                 Mohegan Digital, LLC     2021/22  12/31/2021 12:00:00 AM
# 115  MPI Master Wagering License CT, LLC     2021/22  11/30/2021 12:00:00 AM
# 116                 Mohegan Digital, LLC     2021/22  11/30/2021 12:00:00 AM
# 117  MPI Master Wagering License CT, LLC     2021/22  10/31/2021 12:00:00 AM
# 118                 Mohegan Digital, LLC     2021/22  10/31/2021 12:00:00 AM
#
# ...

# %%
print(data.head())
# Out:
#                               Licensee Fiscal Year            Month Ending  \
# 0         Mohegan Tribe On-Reservation     2023/24  05/31/2024 12:00:00 AM
# 1                  MPTN On-Reservation     2023/24  05/31/2024 12:00:00 AM
# 2  MPI Master Wagering License CT, LLC     2023/24  05/31/2024 12:00:00 AM
# 3                 Mohegan Digital, LLC     2023/24  05/31/2024 12:00:00 AM
# 4         Mohegan Tribe On-Reservation     2023/24  04/30/2024 12:00:00 AM
#
#       Wagers  Patron Winnings  Cancelled Wagers  \
# 0    1605437          1567452                 5
# 1    1563906          1512558               127
# 2  752954349        726763463            764875
# 3  617154241        595462209            876998
# 4    2134318          2099254                70
#
#    Online Casino Gaming Win/(Loss)  \
# 0                            37980
# 1                            51221
# 2                         25426010
# 3                         20815035
# 4                            34994
#
# ...

# %%
# Data overview and summary statistics 
print(data.info())
print(data.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119 entries, 0 to 118
# Data columns (total 11 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Licensee                                    119 non-null    object
#  1   Fiscal Year                                 119 non-null    object
#  2   Month Ending                                119 non-null    object
#  3   Wagers                                      119 non-null    int64
#  4   Patron Winnings                             119 non-null    int64
#  5   Cancelled Wagers                            119 non-null    int64
#  6   Online Casino Gaming Win/(Loss)             119 non-null    int64
#  7   Promotional Coupons or Credits Wagered (3)  119 non-null    int64
#  8   Promotional Deduction (4)                   119 non-null    int64
#  9   Total Gross Gaming Revenue                  119 non-null    int64
# ...

# %%
# Check for missing values
print(data.isnull().sum())
# Out:
# Licensee                                      0
# Fiscal Year                                   0
# Month Ending                                  0
# Wagers                                        0
# Patron Winnings                               0
# Cancelled Wagers                              0
# Online Casino Gaming Win/(Loss)               0
# Promotional Coupons or Credits Wagered (3)    0
# Promotional Deduction (4)                     0
# Total Gross Gaming Revenue                    0
# Payment (5)                                   0
# dtype: int64

# %% [markdown]
# ### Histogram and Distribution visualizations

# %%
#Histogram Big Game (data)
data.hist(bins = 20, figsize=(12, 9))
plt.show()

# %% [markdown]
# ### statistics
# to understand the average sales, the range of sales, and the variation in sales figures.

# %%
# Creating Sales colunm
data['Sales'] = data['Payment (5)']

# %%
print(data.head())
# Out:
#                               Licensee Fiscal Year            Month Ending  \
# 0         Mohegan Tribe On-Reservation     2023/24  05/31/2024 12:00:00 AM
# 1                  MPTN On-Reservation     2023/24  05/31/2024 12:00:00 AM
# 2  MPI Master Wagering License CT, LLC     2023/24  05/31/2024 12:00:00 AM
# 3                 Mohegan Digital, LLC     2023/24  05/31/2024 12:00:00 AM
# 4         Mohegan Tribe On-Reservation     2023/24  04/30/2024 12:00:00 AM
#
#       Wagers  Patron Winnings  Cancelled Wagers  \
# 0    1605437          1567452                 5
# 1    1563906          1512558               127
# 2  752954349        726763463            764875
# 3  617154241        595462209            876998
# 4    2134318          2099254                70
#
#    Online Casino Gaming Win/(Loss)  \
# 0                            37980
# 1                            51221
# 2                         25426010
# 3                         20815035
# 4                            34994
#
# ...

# %%
# Creating Average sales, range of sales & variationnn in sales figures.
average_sales = data['Sales'].mean()
sales_range = data['Sales'].max() - data['Sales'].min()
variance_sales = data['Sales'].var()

# %%
print(f"Average Sales: {average_sales}")
print(f"Range of Sales: {sales_range}")
print(f"Variance of Sales: {variance_sales}")
# Out:
# Average Sales: 1182298.8403361344
# Range of Sales: 4106803
# Variance of Sales: 1547294249454.6096

# %% [markdown]
# ### Correlationn Analysis

# %%
data = data.drop(columns=['Licensee', 'Fiscal Year', 'Month Ending', 'Sales'])

# %%
data.head()
# Out:
#       Wagers  Patron Winnings  Cancelled Wagers  \
# 0    1605437          1567452                 5
# 1    1563906          1512558               127
# 2  752954349        726763463            764875
# 3  617154241        595462209            876998
# 4    2134318          2099254                70
#
#    Online Casino Gaming Win/(Loss)  \
# 0                            37980
# 1                            51221
# 2                         25426010
# 3                         20815035
# 4                            34994
#
#    Promotional Coupons or Credits Wagered (3)  Promotional Deduction (4)  \
# 0                                       10302                       5697
# 1                                       11930                       7683
# 2                                     4198571                    3813902
# 3                                     4457553                    3122255
# 4                                        5418                       5249
#
# ...

# %%
# Correlation Matrix

corr_matrix = data.corr()

# %%
corr_matrix
# Out:
#                                               Wagers  Patron Winnings  \
# Wagers                                      1.000000         0.999985
# Patron Winnings                             0.999985         1.000000
# Cancelled Wagers                            0.740603         0.738689
# Online Casino Gaming Win/(Loss)             0.986923         0.986031
# Promotional Coupons or Credits Wagered (3)  0.520166         0.521951
# Promotional Deduction (4)                   0.963207         0.963174
# Total Gross Gaming Revenue                  0.979841         0.978777
# Payment (5)                                 0.979837         0.978772
#
#                                             Cancelled Wagers  \
# Wagers                                              0.740603
# Patron Winnings                                     0.738689
# Cancelled Wagers                                    1.000000
# Online Casino Gaming Win/(Loss)                     0.776792
# ...

# %%
plt.figure(figsize=(10, 6))
plot = sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# #  bar charts and scatter plots
# ### bar charts

# %%
file = 'Selected_Online_Casino_Gaming_Data.csv'
data = pd.read_csv(file)
data['Sales'] = data['Payment (5)']

# %%
data.head()
# Out:
#                               Licensee Fiscal Year            Month Ending  \
# 0         Mohegan Tribe On-Reservation     2023/24  05/31/2024 12:00:00 AM
# 1                  MPTN On-Reservation     2023/24  05/31/2024 12:00:00 AM
# 2  MPI Master Wagering License CT, LLC     2023/24  05/31/2024 12:00:00 AM
# 3                 Mohegan Digital, LLC     2023/24  05/31/2024 12:00:00 AM
# 4         Mohegan Tribe On-Reservation     2023/24  04/30/2024 12:00:00 AM
#
#       Wagers  Patron Winnings  Cancelled Wagers  \
# 0    1605437          1567452                 5
# 1    1563906          1512558               127
# 2  752954349        726763463            764875
# 3  617154241        595462209            876998
# 4    2134318          2099254                70
#
#    Online Casino Gaming Win/(Loss)  \
# 0                            37980
# 1                            51221
# 2                         25426010
# 3                         20815035
# 4                            34994
#
# ...

# %%
# bar chart for Licensee
licensee = data['Licensee']
sales = data['Sales']

# %%
fig = plt.figure(figsize=(15, 10))
plt.bar(licensee, sales, color='olive')
plt.xlabel('licensee')
plt.ylabel('sales')
plt.title('Licensee')
plt.show()

# %%
# bar chart for Fiscal Year
fiscal_year = data['Fiscal Year']
sales = data['Sales']

# %%
fig = plt.figure(figsize=(15, 10))
plt.bar(fiscal_year, sales, color='navy')
plt.xlabel('fiscal_year')
plt.ylabel('sales')
plt.title('Fiscal Year')
plt.show()

# %%
# bar chart for Month Ending
month_ending = data['Month Ending']
sales = data['Sales']

# %%
fig = plt.figure(figsize=(15, 10))
plt.bar(month_ending, sales, color='maroon')
plt.xlabel('month_ending')
plt.ylabel('sales')
plt.title('Month Ending')
plt.show()

# %% [markdown]
# ### Scatter plots

# %%
# Scatter plot for Licensee
x = licensee
y = sales


fig = plt.figure(figsize=(15, 10))
plt.scatter(x,y)
plt.colorbar(label = 'Color Values')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter Plot for Licensee')
plt.show()

# %%
# Scatter plot for Fiscal Year
x = fiscal_year
y = sales

fig = plt.figure(figsize=(15, 10))
plt.scatter(x,y)
plt.colorbar(label = 'Color Values')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter Plot for Fiscal Year')
plt.show()

# %%
# Scatter plot for Month Ending
x = month_ending
y = sales

fig = plt.figure(figsize=(15, 10))
plt.scatter(x,y)
plt.colorbar(label = 'Color Values')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter Plot for Month Ending')
plt.show()

# %%
data.head()
# Out:
#                               Licensee Fiscal Year            Month Ending  \
# 0         Mohegan Tribe On-Reservation     2023/24  05/31/2024 12:00:00 AM
# 1                  MPTN On-Reservation     2023/24  05/31/2024 12:00:00 AM
# 2  MPI Master Wagering License CT, LLC     2023/24  05/31/2024 12:00:00 AM
# 3                 Mohegan Digital, LLC     2023/24  05/31/2024 12:00:00 AM
# 4         Mohegan Tribe On-Reservation     2023/24  04/30/2024 12:00:00 AM
#
#       Wagers  Patron Winnings  Cancelled Wagers  \
# 0    1605437          1567452                 5
# 1    1563906          1512558               127
# 2  752954349        726763463            764875
# 3  617154241        595462209            876998
# 4    2134318          2099254                70
#
#    Online Casino Gaming Win/(Loss)  \
# 0                            37980
# 1                            51221
# 2                         25426010
# 3                         20815035
# 4                            34994
#
# ...

# %% [markdown]
# ### Segment
# data by regions and compare the performance of different game titles ad also how sales figures vary by platform

# %%
## perform groupby on categories
print(data.groupby(['Licensee']).size())
# Out:
# Licensee
# MPI Master Wagering License CT, LLC    32
# MPTN On-Reservation                    30
# Mohegan Digital, LLC                   32
# Mohegan Tribe On-Reservation           25
# dtype: int64

# %%
## perform groupby on categories related to sales
data.groupby(['Licensee'], as_index=False)['Sales'].sum()
# Out:
#                               Licensee     Sales
# 0  MPI Master Wagering License CT, LLC  79548981
# 1                  MPTN On-Reservation    168635
# 2                 Mohegan Digital, LLC  60843695
# 3         Mohegan Tribe On-Reservation    132251
